# %% [markdown]
# # 1.Fase de análisis y descripción de pcaps minados

# %% [markdown]
# ---

# %% [markdown]
# ## Imports

# %%
from IPython.display import display, Image

# %% [markdown]
# ---

# %%
display(Image(filename='Resources/data.png'))

# %% [markdown]
# ---

# %%
import pandas as pd

# %% [markdown]
# ---

# %% [markdown]
# En esta fase se realizará la extracción de los pcaps necesarios para nuestra investigación. Las **actividades** son:

# %% [markdown]
#     a.	Obtener una muestra de capturas de tráfico de red de ataques de botnets para su posterior análisis

# %% [markdown]
# En esta fase, nuestros **entregables** son:

# %% [markdown]
# 1. Conjunto de pcaps estructurados en benignos y malignos
# 2. Análisis preliminar de los pcaps, detallando fuentes de extracción y herramientas utilizadas para ello

# %% [markdown]
# ----

# %% [markdown]
# ---

# %% [markdown]
# ## Entregables

# %% [markdown]
# ---

# %% [markdown]
# ### Fuentes de extracción

# %% [markdown]
# Se procedio a la descarga de una serie de pcaps provistos por el laboratorio https://www.stratosphereips.org/

# %% [markdown]
# ### 1. Benignos

# %%
s_benigns = pd.read_csv(r"C:\Users\Usuario\Documents\Github\PDG\PDG-2\PCAPS\Information about pcapc benigns.csv", delimiter = ";")

# %%
s_benigns
# Out:
#     Reference                                               Link  \
# 0           1  https://mcfp.felk.cvut.cz/publicDatasets/CTU-N...
# 1           2  https://mcfp.felk.cvut.cz/publicDatasets/CTU-N...
# 2           3  https://mcfp.felk.cvut.cz/publicDatasets/CTU-N...
# 3           4  https://mcfp.felk.cvut.cz/publicDatasets/CTU-N...
# 4           5  https://mcfp.felk.cvut.cz/publicDatasets/CTU-N...
# 5           6  https://mcfp.felk.cvut.cz/publicDatasets/CTU-N...
# 6           7  https://mcfp.felk.cvut.cz/publicDatasets/CTU-N...
# 7           8  https://mcfp.felk.cvut.cz/publicDatasets/CTU-N...
# 8           9  https://mcfp.felk.cvut.cz/publicDatasets/CTU-N...
# 9          10  https://mcfp.felk.cvut.cz/publicDatasets/CTU-N...
# 10         11  https://mcfp.felk.cvut.cz/publicDatasets/CTU-N...
# 11         12  https://mcfp.felk.cvut.cz/publicDatasets/CTU-N...
# 12         13  https://mcfp.felk.cvut.cz/publicDatasets/CTU-N...
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### 2. Malignos

# %%
s_maligns = pd.read_csv(r"C:\Users\Usuario\Documents\Github\PDG\PDG-2\PCAPS\Information about pcaps Maligns.csv", delimiter = ";")

# %%
s_maligns
# Out:
#     Ref                                           Download         Pcap Name
# 0     1  https://mcfp.felk.cvut.cz/publicDatasets/CTU-M...  2018-05-03_win12
# 1     2  https://mcfp.felk.cvut.cz/publicDatasets/CTU-M...    162.222.213.28
# 2     3  https://mcfp.felk.cvut.cz/publicDatasets/CTU-M...  2018-04-04_win16
# 3     4  https://mcfp.felk.cvut.cz/publicDatasets/CTU-M...  2018-04-03_win12
# 4     5  https://mcfp.felk.cvut.cz/publicDatasets/CTU-M...  2018-04-03_win11
# ..  ...                                                ...               ...
# 75   76  https://mcfp.felk.cvut.cz/publicDatasets/CTU-M...   2017-06-24_win8
# 76   77  https://mcfp.felk.cvut.cz/publicDatasets/CTU-M...   2017-06-24_win7
# 77   78  https://mcfp.felk.cvut.cz/publicDatasets/CTU-M...   2017-06-24_win6
# 78   79  https://mcfp.felk.cvut.cz/publicDatasets/CTU-M...   2017-06-24_win5
# 79   80  https://mcfp.felk.cvut.cz/publicDatasets/CTU-M...   2017-06-24_win4
#
# [80 rows x 3 columns]
