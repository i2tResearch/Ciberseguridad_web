# %% [markdown]
# ---

# %% [markdown]
# # Step_3.2: Comparison Between Stratosphere's Benign Dataset and Our Benign Dataset for probe the ML Algorithms

# %% [markdown]
# ---

# %% [markdown]
# ### 1. Imports

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np #operaciones matriciales y con vectores
import pandas as pd #tratamiento de datos
import random
import matplotlib.pyplot as plt #gráficos
import seaborn as sns
import joblib

# %%
from sklearn import preprocessing

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ### 2. Load Own Benign Dataset

# %%
b_research = pd.read_csv(r"C:\Users\Usuario\Documents\Github\PDG\PDG-2\Datasets\Time Window\TEST\testB1.csv", delimiter = ",")

# %%
b_research.head()
# Out:
#              Name  Netflows First_Protocol Second_Protocol Third_Protocol  \
# 0  23-csves/0.csv       194            UDP             TCP           IGMP
# 1  23-csves/1.csv       166            UDP             TCP           IGMP
# 2  23-csves/2.csv       161            UDP             TCP           IGMP
# 3  23-csves/3.csv       263            UDP             TCP           ICMP
# 4  23-csves/4.csv       177            UDP             TCP           IGMP
#
#    p1_d   p2_d       p3_d   duration    max_d  ...  first_dp  second_dp  \
# 0   0.0  0.000   10.20150  10324.970  299.971  ...       443       1900
# 1   0.0  0.033  124.86375  11250.986  284.470  ...       443      52122
# 2   0.0  0.000   15.16900   9879.502  299.979  ...       443       1900
# 3   0.0  0.000    7.30350  11424.463  299.994  ...       443       1900
# 4   0.0  0.000   65.46600  10823.177  299.989  ...       443      52122
#
#    third_dp  p1_ip  p2_ip  p3_ip  p1_ib  p2_ib    p3_ib    Type
# 0     52122    1.0    1.0    9.0  40.25   97.5  1074.50  Benign
# 1      1900    1.0    2.0   10.0  37.00  136.5  1304.75  Benign
# 2     52122    1.0    1.0   10.0  37.00  133.0  1084.00  Benign
# 3         0    1.0    1.0   10.0  40.00  100.0  1152.50  Benign
# 4      1900    1.0    2.0   10.0  37.00  126.0  1104.00  Benign
#
# [5 rows x 31 columns]

# %%
b_research.loc[b_research.Type == "Benign", ['Type']] = 'Own'

# %%
b_research.head(2)
# Out:
#              Name  Netflows First_Protocol Second_Protocol Third_Protocol  \
# 0  23-csves/0.csv       194            UDP             TCP           IGMP
# 1  23-csves/1.csv       166            UDP             TCP           IGMP
#
#    p1_d   p2_d       p3_d   duration    max_d  ...  first_dp  second_dp  \
# 0   0.0  0.000   10.20150  10324.970  299.971  ...       443       1900
# 1   0.0  0.033  124.86375  11250.986  284.470  ...       443      52122
#
#    third_dp  p1_ip  p2_ip  p3_ip  p1_ib  p2_ib    p3_ib  Type
# 0     52122    1.0    1.0    9.0  40.25   97.5  1074.50   Own
# 1      1900    1.0    2.0   10.0  37.00  136.5  1304.75   Own
#
# [2 rows x 31 columns]

# %% [markdown]
# ---

# %% [markdown]
# ### 3. Load Stratosphere Dataset

# %%
b_stratosphere = pd.read_csv(r"C:\Users\Usuario\Documents\Github\PDG\PDG-2\Datasets\Time Window\Originals\Benigns v2\BeningTimeWindowsStratosphere.csv", delimiter = ",")

# %%
b_stratosphere.head()
# Out:
#             Name  Netflows First_Protocol Second_Protocol Third_Protocol  \
# 0  1-csves/0.csv      7846            UDP             TCP            NaN
# 1  1-csves/1.csv     10044            UDP             TCP           ICMP
# 2  1-csves/2.csv      7852            UDP             TCP            NaN
# 3  1-csves/3.csv      5380            UDP             TCP           ICMP
# 4  1-csves/4.csv      6660            UDP             TCP           ICMP
#
#    p1_d  p2_d    p3_d    duration    max_d  ...  first_dp  second_dp  \
# 0   0.0   0.0   9.971  170718.308  291.654  ...        53       80.0
# 1   0.0   0.0   7.072  144468.294  291.495  ...        53      443.0
# 2   0.0   0.0  16.452  186441.984  296.048  ...        53       80.0
# 3   0.0   0.0   7.917   99154.208  291.025  ...        53      443.0
# 4   0.0   0.0   8.056  134871.434  291.589  ...        53       80.0
#
#    third_dp  p1_ip  p2_ip  p3_ip  p1_ib  p2_ib  p3_ib    Type
# 0     443.0    1.0    1.0    8.0   52.0  210.0  494.0  Benign
# 1      80.0    1.0    1.0    4.0   49.0  155.0  430.0  Benign
# 2     443.0    1.0    1.0   10.0   52.0  211.0  634.0  Benign
# 3      80.0    1.0    1.0    7.0   52.0  193.0  435.0  Benign
# 4     443.0    1.0    1.0    6.0   51.0  199.0  434.0  Benign
#
# [5 rows x 31 columns]

# %%
b_stratosphere.loc[b_stratosphere.Type == "Benign", ['Type']] = 'Stratosphere'

# %%
b_stratosphere.head(2)
# Out:
#             Name  Netflows First_Protocol Second_Protocol Third_Protocol  \
# 0  1-csves/0.csv      7846            UDP             TCP            NaN
# 1  1-csves/1.csv     10044            UDP             TCP           ICMP
#
#    p1_d  p2_d   p3_d    duration    max_d  ...  first_dp  second_dp  third_dp  \
# 0   0.0   0.0  9.971  170718.308  291.654  ...        53       80.0     443.0
# 1   0.0   0.0  7.072  144468.294  291.495  ...        53      443.0      80.0
#
#    p1_ip  p2_ip  p3_ip  p1_ib  p2_ib  p3_ib          Type
# 0    1.0    1.0    8.0   52.0  210.0  494.0  Stratosphere
# 1    1.0    1.0    4.0   49.0  155.0  430.0  Stratosphere
#
# [2 rows x 31 columns]

# %% [markdown]
# ---

# %% [markdown]
# ### 4. Join

# %%
frames = [b_research,b_stratosphere]

# %%
full_dataset = pd.concat(frames)
full_dataset.head()
# Out:
#              Name  Netflows First_Protocol Second_Protocol Third_Protocol  \
# 0  23-csves/0.csv       194            UDP             TCP           IGMP
# 1  23-csves/1.csv       166            UDP             TCP           IGMP
# 2  23-csves/2.csv       161            UDP             TCP           IGMP
# 3  23-csves/3.csv       263            UDP             TCP           ICMP
# 4  23-csves/4.csv       177            UDP             TCP           IGMP
#
#    p1_d   p2_d       p3_d   duration    max_d  ...  first_dp  second_dp  \
# 0   0.0  0.000   10.20150  10324.970  299.971  ...       443     1900.0
# 1   0.0  0.033  124.86375  11250.986  284.470  ...       443    52122.0
# 2   0.0  0.000   15.16900   9879.502  299.979  ...       443     1900.0
# 3   0.0  0.000    7.30350  11424.463  299.994  ...       443     1900.0
# 4   0.0  0.000   65.46600  10823.177  299.989  ...       443    52122.0
#
#    third_dp  p1_ip  p2_ip  p3_ip  p1_ib  p2_ib    p3_ib  Type
# 0   52122.0    1.0    1.0    9.0  40.25   97.5  1074.50   Own
# 1    1900.0    1.0    2.0   10.0  37.00  136.5  1304.75   Own
# 2   52122.0    1.0    1.0   10.0  37.00  133.0  1084.00   Own
# 3       0.0    1.0    1.0   10.0  40.00  100.0  1152.50   Own
# 4    1900.0    1.0    2.0   10.0  37.00  126.0  1104.00   Own
#
# [5 rows x 31 columns]

# %%
full_dataset.columns
# Out:
# Index(['Name', 'Netflows', 'First_Protocol', 'Second_Protocol',
#        'Third_Protocol', 'p1_d', 'p2_d', 'p3_d', 'duration', 'max_d', 'min_d',
#        'packets', 'Avg_bps', 'Avg_pps', 'Avg_bpp', 'Bytes', 'number_sp',
#        'number_dp', 'first_sp', 'second_sp', 'third_sp', 'first_dp',
#        'second_dp', 'third_dp', 'p1_ip', 'p2_ip', 'p3_ip', 'p1_ib', 'p2_ib',
#        'p3_ib', 'Type'],
#       dtype='object')

# %%
full_dataset.dtypes
# Out:
# Name                object
# Netflows             int64
# First_Protocol      object
# Second_Protocol     object
# Third_Protocol      object
# p1_d               float64
# p2_d               float64
# p3_d               float64
# duration           float64
# max_d              float64
# min_d              float64
# packets              int64
# Avg_bps              int64
# Avg_pps              int64
# Avg_bpp              int64
# Bytes                int64
# number_sp            int64
# number_dp            int64
# first_sp             int64
# second_sp          float64
# third_sp           float64
# first_dp             int64
# second_dp          float64
# third_dp           float64
# p1_ip              float64
# p2_ip              float64
# p3_ip              float64
# p1_ib              float64
# p2_ib              float64
# p3_ib              float64
# Type                object
# dtype: object

# %%
full_dataset['First_Protocol'] = full_dataset['First_Protocol'].replace(np.nan,"None",regex=True)
full_dataset['Second_Protocol'] = full_dataset['Second_Protocol'].replace(np.nan,"None",regex=True)
full_dataset['Third_Protocol'] = full_dataset['Third_Protocol'].replace(np.nan,"None",regex=True)

# %%
full_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1152 entries, 0 to 518
# Data columns (total 31 columns):
# Name               1152 non-null object
# Netflows           1152 non-null int64
# First_Protocol     1152 non-null object
# Second_Protocol    1152 non-null object
# Third_Protocol     1152 non-null object
# p1_d               1152 non-null float64
# p2_d               1152 non-null float64
# p3_d               1152 non-null float64
# duration           1152 non-null float64
# max_d              1152 non-null float64
# min_d              1152 non-null float64
# packets            1152 non-null int64
# Avg_bps            1152 non-null int64
# Avg_pps            1152 non-null int64
# Avg_bpp            1152 non-null int64
# Bytes              1152 non-null int64
# number_sp          1152 non-null int64
# number_dp          1152 non-null int64
# first_sp           1152 non-null int64
# second_sp          1151 non-null float64
# third_sp           1143 non-null float64
# first_dp           1152 non-null int64
# second_dp          1151 non-null float64
# third_dp           1143 non-null float64
# p1_ip              1152 non-null float64
# p2_ip              1152 non-null float64
# p3_ip              1152 non-null float64
# p1_ib              1152 non-null float64
# p2_ib              1152 non-null float64
# p3_ib              1152 non-null float64
# Type               1152 non-null object
# dtypes: float64(16), int64(10), object(5)
# memory usage: 288.0+ KB

# %% [markdown]
# ---

# %% [markdown]
# ## 5. Drop Columns that are useless...

# %%
full_dataset = full_dataset.drop(['Name','Third_Protocol','p1_d','max_d','min_d','packets','Avg_pps'
                                           ,'Avg_bpp','second_sp','third_sp','first_dp','second_dp','third_dp'
                                           ,'p1_ip','p2_ip','p3_ip','Second_Protocol','Netflows'], axis=1)

# %% [markdown]
# ---

# %% [markdown]
# ## 6. Dictionary

# %% [markdown]
# Let's instantiate the **Encoder**:

# %%
le = joblib.load('./Tools/label_encoder.joblib')

# %% [markdown]
# ---

# %% [markdown]
# In the column of **First_Protocol**:

# %%
full_dataset.First_Protocol.unique()
# Out:
# array(['UDP', 'TCP', 'ICMP'], dtype=object)

# %%
first_protocol_column_codified = le.fit_transform(full_dataset.First_Protocol)

# %%
le_name_mapping_first_protocol = dict(zip(le.classes_, le.transform(le.classes_)))
print(le_name_mapping_first_protocol)
# Out:
# {'ICMP': 0, 'TCP': 1, 'UDP': 2}

# %%
full_dataset.First_Protocol = le.fit_transform(full_dataset.First_Protocol)

# %% [markdown]
# ---

# %% [markdown]
# In the column of **Type**:

# %%
full_dataset.Type.unique()
# Out:
# array(['Own', 'Stratosphere'], dtype=object)

# %%
Type_protocol_column_codified = le.fit_transform(full_dataset.Type)

# %%
le_name_mapping_type = dict(zip(le.classes_, le.transform(le.classes_)))
print(le_name_mapping_type)
# Out:
# {'Own': 0, 'Stratosphere': 1}

# %%
full_dataset.Type = le.fit_transform(full_dataset.Type)

# %% [markdown]
# ---

# %% [markdown]
# ### 6. Plots

# %%
full_dataset.columns
# Out:
# Index(['First_Protocol', 'p2_d', 'p3_d', 'duration', 'Avg_bps', 'Bytes',
#        'number_sp', 'number_dp', 'first_sp', 'p1_ib', 'p2_ib', 'p3_ib',
#        'Type'],
#       dtype='object')

# %%
len(full_dataset.columns)
# Out:
# 13

# %%
for column in full_dataset.iloc[:,:-1].columns:  
    if column != "First_Protocol" and column != "Type":
         fig, (ax1) = plt.subplots(ncols=1, figsize =(20,10))
         ax1.set_title("Distribution in column %s per Type" %column)
         sns.kdeplot(full_dataset[full_dataset.Type == 0][column], color="green", shade=True)
         sns.kdeplot(full_dataset[full_dataset.Type == 1][column], color="blue", shade=True)
         plt.legend(['Own', 'Stratosphere'])

# %% [markdown]
# ---

# %%
column = "First_Protocol"
temp =  full_dataset[[column,"Type"]]

# %%
le_name_mapping_type
# Out:
# {'Own': 0, 'Stratosphere': 1}

# %%
fig, (ax1) = plt.subplots(ncols=1, figsize =(20,20))
ax1.set_title("Distribution in column %s" %column)
sns.countplot(x=column, hue="Type",data=full_dataset[[column,"Type"]])

# %%
le_name_mapping_first_protocol
# Out:
# {'ICMP': 0, 'TCP': 1, 'UDP': 2}

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---
