# %% [markdown]
# # Step_2 : Joining the cleaned datasets

# %% [markdown]
# ---

# %% [markdown]
# ## 1. Imports

# %%
import pandas as pd #tratamiento de datos

# %% [markdown]
# ## 2. Let's load Stratosphere's Benign Dataset

# %%
stratosphere_benign_dataset = pd.read_csv(r"C:\Users\Usuario\Documents\Github\PDG\PDG-2\Datasets\Time Window\Cleaned\CleanedStratosphersBenignDataset.csv", delimiter = ",")

# %%
stratosphere_benign_dataset.head()
# Out:
#             Name  Netflows First_Protocol Second_Protocol Third_Protocol  \
# 0  1-csves/0.csv      7846            UDP             TCP           None
# 1  1-csves/1.csv     10044            UDP             TCP           ICMP
# 2  1-csves/2.csv      7852            UDP             TCP           None
# 3  1-csves/3.csv      5380            UDP             TCP           ICMP
# 4  1-csves/4.csv      6660            UDP             TCP           ICMP
#
#    p1_d  p2_d    p3_d    duration    max_d  ...  first_dp  second_dp  \
# 0   0.0   0.0   9.971  170718.308  291.654  ...        53         80
# 1   0.0   0.0   7.072  144468.294  291.495  ...        53        443
# 2   0.0   0.0  16.452  186441.984  296.048  ...        53         80
# 3   0.0   0.0   7.917   99154.208  291.025  ...        53        443
# 4   0.0   0.0   8.056  134871.434  291.589  ...        53         80
#
#    third_dp  p1_ip  p2_ip  p3_ip  p1_ib  p2_ib  p3_ib    Type
# ...

# %%
stratosphere_benign_dataset.shape
# Out:
# (516, 31)

# %% [markdown]
# ## 3. Let's load Stratosphere's Malign Dataset

# %%
stratosphere_malign_dataset = pd.read_csv(r"C:\Users\Usuario\Documents\Github\PDG\PDG-2\Datasets\Time Window\Cleaned\CleanedStratosphersMalignDataset.csv", delimiter = ",")

# %%
stratosphere_malign_dataset.head()
# Out:
#                 Name  Netflows First_Protocol Second_Protocol Third_Protocol  \
# 0  32-csves/3257.csv       174           None            IGMP          ICMP6
# 1   1-csves/4317.csv       270           None            IGMP            UDP
# 2   9-csves/7488.csv       320           None           ICMP6           IGMP
# 3   8-csves/3288.csv       256           None           ICMP6           IGMP
# 4  79-csves/2249.csv         6            TCP            None           None
#
#       p1_d   p2_d      p3_d  duration    max_d  ...  first_dp  second_dp  \
# 0  0.00000  0.000   0.00000     0.000    0.000  ...         0      34304
# 1  0.00000  0.000   0.00000    18.242    3.046  ...         0      34560
# 2  0.00000  0.000   0.00000     0.000    0.000  ...         0      34560
# 3  0.00000  0.000   0.00000  1161.318  290.454  ...         0      34560
# 4  0.00725  0.026  95.67875   255.180  127.563  ...       443      51047
#
#    third_dp  p1_ip  p2_ip  p3_ip  p1_ib  p2_ib   p3_ib    Type
# ...

# %%
stratosphere_malign_dataset.shape
# Out:
# (193631, 31)

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## 4. Let's join Benign and Malign Dataset from Stratosphere

# %%
frames = [stratosphere_benign_dataset,stratosphere_malign_dataset]

# %%
BM_Stratosphere = pd.concat(frames)

# %%
BM_Stratosphere
# Out:
#                       Name  Netflows First_Protocol Second_Protocol  \
# 0            1-csves/0.csv      7846            UDP             TCP
# 1            1-csves/1.csv     10044            UDP             TCP
# 2            1-csves/2.csv      7852            UDP             TCP
# 3            1-csves/3.csv      5380            UDP             TCP
# 4            1-csves/4.csv      6660            UDP             TCP
# ...                    ...       ...            ...             ...
# 193626  26-csves/10471.csv       382           None           ICMP6
# 193627  29-csves/11325.csv       340           None           ICMP6
# 193628    5-csves/4279.csv       330           None           ICMP6
# 193629    6-csves/2064.csv       236           None             UDP
# 193630     8-csves/856.csv       252           None           ICMP6
#
#        Third_Protocol  p1_d  p2_d    p3_d    duration    max_d  ...  first_dp  \
# ...

# %%
BM_Stratosphere.dtypes
# Out:
# Name                object
# Netflows             int64
# First_Protocol      object
# Second_Protocol     object
# Third_Protocol      object
# p1_d               float64
# p2_d               float64
# p3_d               float64
# duration           float64
# max_d              float64
# min_d              float64
# packets              int64
# Avg_bps              int64
# Avg_pps              int64
# Avg_bpp              int64
# Bytes                int64
# number_sp            int64
# number_dp            int64
# first_sp             int64
# second_sp            int64
# third_sp             int64
# first_dp             int64
# second_dp            int64
# third_dp             int64
# p1_ip              float64
# p2_ip              float64
# p3_ip              float64
# p1_ib              float64
# p2_ib              float64
# p3_ib              float64
# Type                object
# dtype: object

# %% [markdown]
# Let's **shuffle** the dataset:

# %%
BM_Stratosphere = BM_Stratosphere.sample(frac=1)
BM_Stratosphere.head()
# Out:
#                       Name  Netflows First_Protocol Second_Protocol  \
# 127417   24-csves/5221.csv       278           None             TCP
# 84312    26-csves/3766.csv       184           None           ICMP6
# 16386     78-csves/235.csv        14            TCP            None
# 72236    29-csves/9248.csv       186           None            IGMP
# 16515   32-csves/12833.csv       168           None            IGMP
#
#        Third_Protocol     p1_d   p2_d     p3_d  duration    max_d  ...  \
# 127417           IGMP  0.00000  0.000  0.00000   118.792    9.013  ...
# 84312            IGMP  0.00000  0.000  0.00000   542.294  131.072  ...
# 16386            None  0.09675  0.316  0.56575   257.749  127.249  ...
# 72236           ICMP6  0.00000  0.000  0.00000     0.000    0.000  ...
# 16515            None  0.00000  0.000  0.00000     0.000    0.000  ...
#
#         first_dp  second_dp  third_dp  p1_ip  p2_ip  p3_ip  p1_ib  p2_ib  \
# ...

# %% [markdown]
# ## 5. Let's save the B/M Only Stratosphere Dataset...

# %%
BM_Stratosphere.to_csv(r"C:\Users\Usuario\Documents\Github\PDG\PDG-2\Datasets\Time Window\Cleaned\BMOnlyStratosphere.csv",sep=',',index=False)
