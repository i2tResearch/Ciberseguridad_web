# %% [markdown]
# # Experiment -I

# %% [markdown]
# ---

# %% [markdown]
# # Stratosphere's Benign Dataset vs Our Benign Dataset Generated

# %% [markdown]
# ---

# %% [markdown]
# ### 1. Imports

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np #operaciones matriciales y con vectores
import pandas as pd #tratamiento de datos
import random
import matplotlib.pyplot as plt #gráficos
import seaborn as sns

# %%
import joblib

# %%
from sklearn import preprocessing

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ### 2. Load Own Benign Dataset

# %%
b_research = pd.read_csv(r"C:\Users\Usuario\Documents\Github\PDG\PDG-2\Datasets\Time Window\Originals\Benigns\BenignTimeWindowsOurLab.csv", delimiter = ",")

# %%
b_research.head()
# Out:
#              Name  Netflows First_Protocol Second_Protocol Third_Protocol  \
# 0  19-csves/0.csv       649            UDP             TCP            NaN
# 1  19-csves/1.csv       678            UDP             TCP            NaN
# 2  19-csves/2.csv       567            UDP             TCP            NaN
# 3  19-csves/3.csv       401            UDP             TCP            NaN
# 4  19-csves/4.csv       792            UDP             TCP            NaN
#
#    p1_d    p2_d     p3_d   duration    max_d  ...  first_dp  second_dp  \
# 0   0.0  1.2750   8.0870  12245.608  299.786  ...       137        138
# 1   0.0  1.3260  10.2180  17636.730  299.856  ...       137        138
# 2   0.0  1.4380  16.3465  25171.533  285.001  ...       137        443
# 3   0.0  0.0000   0.4100    503.453   31.028  ...        53       5355
# 4   0.0  0.7815   2.6615  10706.867  298.947  ...       137        138
#
#    third_dp  p1_ip  p2_ip  p3_ip  p1_ib  p2_ib   p3_ib    Type
# 0     57621    1.0    3.0    7.0   58.0  209.0   912.0  Benign
# 1     57621    1.0    3.0    8.0   58.0  228.0  1456.0  Benign
# 2       138    1.0    3.0    6.0   58.0  166.0   375.0  Benign
# 3       137    1.0    1.0    2.0   49.0   72.0   292.0  Benign
# 4     57621    1.0    2.0    5.0   58.0  174.0   406.0  Benign
#
# [5 rows x 31 columns]

# %%
b_research.loc[b_research.Type == "Benign", ['Type']] = 'Own'

# %%
b_research.head(2)
# Out:
#              Name  Netflows First_Protocol Second_Protocol Third_Protocol  \
# 0  19-csves/0.csv       649            UDP             TCP            NaN
# 1  19-csves/1.csv       678            UDP             TCP            NaN
#
#    p1_d   p2_d    p3_d   duration    max_d  ...  first_dp  second_dp  \
# 0   0.0  1.275   8.087  12245.608  299.786  ...       137        138
# 1   0.0  1.326  10.218  17636.730  299.856  ...       137        138
#
#    third_dp  p1_ip  p2_ip  p3_ip  p1_ib  p2_ib   p3_ib  Type
# 0     57621    1.0    3.0    7.0   58.0  209.0   912.0   Own
# 1     57621    1.0    3.0    8.0   58.0  228.0  1456.0   Own
#
# [2 rows x 31 columns]

# %% [markdown]
# ---

# %% [markdown]
# ### 3. Load Stratosphere Dataset

# %%
b_stratosphere = pd.read_csv(r"C:\Users\Usuario\Documents\Github\PDG\PDG-2\Datasets\Time Window\Originals\Benigns\BeningTimeWindowsStratosphere.csv", delimiter = ",")

# %%
b_stratosphere.head()
# Out:
#             Name  Netflows First_Protocol Second_Protocol Third_Protocol  \
# 0  1-csves/0.csv      7846            UDP             TCP            NaN
# 1  1-csves/1.csv     10044            UDP             TCP           ICMP
# 2  1-csves/2.csv      7852            UDP             TCP            NaN
# 3  1-csves/3.csv      5380            UDP             TCP           ICMP
# 4  1-csves/4.csv      6660            UDP             TCP           ICMP
#
#    p1_d  p2_d    p3_d    duration    max_d  ...  first_dp  second_dp  \
# 0   0.0   0.0   9.971  170718.308  291.654  ...        53       80.0
# 1   0.0   0.0   7.072  144468.294  291.495  ...        53      443.0
# 2   0.0   0.0  16.452  186441.984  296.048  ...        53       80.0
# 3   0.0   0.0   7.917   99154.208  291.025  ...        53      443.0
# 4   0.0   0.0   8.056  134871.434  291.589  ...        53       80.0
#
#    third_dp  p1_ip  p2_ip  p3_ip  p1_ib  p2_ib  p3_ib    Type
# 0     443.0    1.0    1.0    8.0   52.0  210.0  494.0  Benign
# 1      80.0    1.0    1.0    4.0   49.0  155.0  430.0  Benign
# 2     443.0    1.0    1.0   10.0   52.0  211.0  634.0  Benign
# 3      80.0    1.0    1.0    7.0   52.0  193.0  435.0  Benign
# 4     443.0    1.0    1.0    6.0   51.0  199.0  434.0  Benign
#
# [5 rows x 31 columns]

# %%
b_stratosphere.loc[b_stratosphere.Type == "Benign", ['Type']] = 'Stratosphere'

# %%
b_stratosphere.head(2)
# Out:
#             Name  Netflows First_Protocol Second_Protocol Third_Protocol  \
# 0  1-csves/0.csv      7846            UDP             TCP            NaN
# 1  1-csves/1.csv     10044            UDP             TCP           ICMP
#
#    p1_d  p2_d   p3_d    duration    max_d  ...  first_dp  second_dp  third_dp  \
# 0   0.0   0.0  9.971  170718.308  291.654  ...        53       80.0     443.0
# 1   0.0   0.0  7.072  144468.294  291.495  ...        53      443.0      80.0
#
#    p1_ip  p2_ip  p3_ip  p1_ib  p2_ib  p3_ib          Type
# 0    1.0    1.0    8.0   52.0  210.0  494.0  Stratosphere
# 1    1.0    1.0    4.0   49.0  155.0  430.0  Stratosphere
#
# [2 rows x 31 columns]

# %% [markdown]
# ---

# %% [markdown]
# ### 4. Join

# %%
frames = [b_research,b_stratosphere]

# %%
full_dataset = pd.concat(frames)
full_dataset.head()
# Out:
#              Name  Netflows First_Protocol Second_Protocol Third_Protocol  \
# 0  19-csves/0.csv       649            UDP             TCP            NaN
# 1  19-csves/1.csv       678            UDP             TCP            NaN
# 2  19-csves/2.csv       567            UDP             TCP            NaN
# 3  19-csves/3.csv       401            UDP             TCP            NaN
# 4  19-csves/4.csv       792            UDP             TCP            NaN
#
#    p1_d    p2_d     p3_d   duration    max_d  ...  first_dp  second_dp  \
# 0   0.0  1.2750   8.0870  12245.608  299.786  ...       137      138.0
# 1   0.0  1.3260  10.2180  17636.730  299.856  ...       137      138.0
# 2   0.0  1.4380  16.3465  25171.533  285.001  ...       137      443.0
# 3   0.0  0.0000   0.4100    503.453   31.028  ...        53     5355.0
# 4   0.0  0.7815   2.6615  10706.867  298.947  ...       137      138.0
#
#    third_dp  p1_ip  p2_ip  p3_ip  p1_ib  p2_ib   p3_ib  Type
# 0   57621.0    1.0    3.0    7.0   58.0  209.0   912.0   Own
# 1   57621.0    1.0    3.0    8.0   58.0  228.0  1456.0   Own
# 2     138.0    1.0    3.0    6.0   58.0  166.0   375.0   Own
# 3     137.0    1.0    1.0    2.0   49.0   72.0   292.0   Own
# 4   57621.0    1.0    2.0    5.0   58.0  174.0   406.0   Own
#
# [5 rows x 31 columns]

# %%
full_dataset = full_dataset.drop(['Name'], axis=1)

# %%
full_dataset = full_dataset[['first_sp','Avg_bps','p1_ib','duration','number_dp','Bytes'
                                          ,'number_sp','First_Protocol','p2_ib'
                                          ,'first_dp','p3_ib','Netflows','p3_d','Second_Protocol','Type']]

# %%
full_dataset.columns
# Out:
# Index(['first_sp', 'Avg_bps', 'p1_ib', 'duration', 'number_dp', 'Bytes',
#        'number_sp', 'First_Protocol', 'p2_ib', 'first_dp', 'p3_ib', 'Netflows',
#        'p3_d', 'Second_Protocol', 'Type'],
#       dtype='object')

# %%
full_dataset['First_Protocol'] = full_dataset['First_Protocol'].replace(np.nan,"None",regex=True)
full_dataset['Second_Protocol'] = full_dataset['Second_Protocol'].replace(np.nan,"None",regex=True)

# %%
full_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1168 entries, 0 to 518
# Data columns (total 15 columns):
# first_sp           1168 non-null int64
# Avg_bps            1168 non-null int64
# p1_ib              1168 non-null float64
# duration           1168 non-null float64
# number_dp          1168 non-null int64
# Bytes              1168 non-null int64
# number_sp          1168 non-null int64
# First_Protocol     1168 non-null object
# p2_ib              1168 non-null float64
# first_dp           1168 non-null int64
# p3_ib              1168 non-null float64
# Netflows           1168 non-null int64
# p3_d               1168 non-null float64
# Second_Protocol    1168 non-null object
# Type               1168 non-null object
# dtypes: float64(5), int64(7), object(3)
# memory usage: 146.0+ KB

# %% [markdown]
# ---

# %% [markdown]
# ### 5. Dictionary

# %% [markdown]
# Let's instantiate the **Encoder**:

# %%
le = joblib.load("./Tools/label_encoder_first_protocol_exp1.encoder")

# %% [markdown]
# ---

# %% [markdown]
# In the column of **First_Protocol**:

# %%
full_dataset.First_Protocol.unique()
# Out:
# array(['UDP', 'TCP', 'ICMP'], dtype=object)

# %%
first_protocol_column_codified = le.transform(full_dataset.First_Protocol)

# %%
le.classes_
# Out:
# array(['ICMP', 'ICMP6', 'None', 'TCP', 'UDP'], dtype=object)

# %%
le_name_mapping_first_protocol = dict(zip(le.classes_, le.transform(le.classes_)))
print(le_name_mapping_first_protocol)
# Out:
# {'ICMP': 0, 'ICMP6': 1, 'None': 2, 'TCP': 3, 'UDP': 4}

# %%
full_dataset.First_Protocol = le.transform(full_dataset.First_Protocol)

# %% [markdown]
# ---

# %% [markdown]
# In the column of **Second_Protocol**:

# %%
le = joblib.load("./Tools/label_encoder_second_protocol_exp1.encoder")

# %%
full_dataset.Second_Protocol.unique()
# Out:
# array(['TCP', 'UDP', 'ICMP', 'None'], dtype=object)

# %%
second_protocol_column_codified = le.transform(full_dataset.Second_Protocol)

# %%
le.classes_
# Out:
# array(['ICMP', 'ICMP6', 'IGMP', 'None', 'TCP', 'UDP'], dtype=object)

# %%
le_name_mapping_second_protocol = dict(zip(le.classes_, le.transform(le.classes_)))
print(le_name_mapping_second_protocol)
# Out:
# {'ICMP': 0, 'ICMP6': 1, 'IGMP': 2, 'None': 3, 'TCP': 4, 'UDP': 5}

# %%
full_dataset.Second_Protocol = le.transform(full_dataset.Second_Protocol)

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# In the column of **Type**:

# %%
le = preprocessing.LabelEncoder()

# %%
full_dataset.Type.unique()
# Out:
# array(['Own', 'Stratosphere'], dtype=object)

# %%
Type_protocol_column_codified = le.fit_transform(full_dataset.Type)

# %%
le.classes_
# Out:
# array(['Own', 'Stratosphere'], dtype=object)

# %%
le_name_mapping_type = dict(zip(le.classes_, le.transform(le.classes_)))
print(le_name_mapping_type)
# Out:
# {'Own': 0, 'Stratosphere': 1}

# %%
full_dataset.Type = le.transform(full_dataset.Type)

# %% [markdown]
# ---

# %% [markdown]
# ### 6. Plots

# %%
invalid = ["Name","First_Protocol","Second_Protocol","Third_Protocol","Type"]

# %%
for column in full_dataset.columns:  
   if column not in invalid:
         fig, (ax1) = plt.subplots(ncols=1, figsize =(20,10))
         ax1.set_title("Distribution in column %s per Type" %column)
         sns.kdeplot(full_dataset[full_dataset.Type == 0][column], color="green", shade=True)
         sns.kdeplot(full_dataset[full_dataset.Type == 1][column], color="blue", shade=True)
         plt.legend(['Own', 'Stratosphere'])

# %% [markdown]
# ---

# %%
column = "First_Protocol"
temp =  full_dataset[[column,"Type"]]

# %%
le_name_mapping_type
# Out:
# {'Own': 0, 'Stratosphere': 1}

# %%
fig, (ax1) = plt.subplots(ncols=1, figsize =(20,20))
ax1.set_title("Distribution in column %s" %column)
sns.countplot(x=column, hue="Type",data=full_dataset[[column,"Type"]])

# %%
le_name_mapping_first_protocol
# Out:
# {'ICMP': 0, 'ICMP6': 1, 'None': 2, 'TCP': 3, 'UDP': 4}

# %% [markdown]
# ---

# %% [markdown]
# ---

# %%
column = "Second_Protocol"
temp =  full_dataset[[column,"Type"]]

# %%
le_name_mapping_type
# Out:
# {'Own': 0, 'Stratosphere': 1}

# %%
fig, (ax1) = plt.subplots(ncols=1, figsize =(20,20))
ax1.set_title("Distribution in column %s" %column)
sns.countplot(x=column, hue="Type",data=full_dataset[[column,"Type"]])

# %%
le_name_mapping_second_protocol
# Out:
# {'ICMP': 0, 'ICMP6': 1, 'IGMP': 2, 'None': 3, 'TCP': 4, 'UDP': 5}

# %% [markdown]
# ---
