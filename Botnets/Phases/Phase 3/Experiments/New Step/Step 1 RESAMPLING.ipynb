# %% [markdown]
# # Step 1: RESAMPLING

# %% [markdown]
# ---

# %% [markdown]
# ## 1. Imports

# %%
from IPython.display import display, Image

# %%
import pandas as pd

# %% [markdown]
# ---

# %%
display(Image(filename='Resources/resampling.PNG'))

# %% [markdown]
# ## 2. Description

# %% [markdown]
# In our dataset we have the following data :

# %%
BStratosphere = pd.read_csv(r"C:\Users\Usuario\Documents\Github\PDG\PDG-2\Datasets\Time Window\Originals\Benigns\BeningTimeWindowsStratosphere.csv", delimiter = ",")

# %%
BStratosphere.shape
# Out:
# (519, 31)

# %%
MStratosphere = pd.read_csv(r"C:\Users\Usuario\Documents\Github\PDG\PDG-2\Datasets\Time Window\Originals\Maligns\MalignTimeWindowsStratosphere.csv",
                                          delimiter = ",")

# %%
MStratosphere.shape
# Out:
# (258178, 31)

# %% [markdown]
# As we can see, we have only **519** benign data compared with the malign data that is very huge.  The above shows that we have  **IMBALANCED DATA**.

# %% [markdown]
# In a first step, we generate a sample of benign data, trying to make a **OVERSAMPLING** of this type of data. We got the following number of time windows:

# %%
BOurResearch = pd.read_csv(r"C:\Users\Usuario\Documents\Github\PDG\PDG-2\Datasets\Time Window\Originals\Benigns\BenignTimeWindowsOurLab.csv", delimiter = ",")

# %%
BOurResearch.shape
# Out:
# (649, 31)

# %% [markdown]
# If we plus our data and the stratospheres benign data, we can get an approximate of **1.168** benign time windows. But, remains lower that malign data...

# %% [markdown]
# For this reason, we choose to apply a **UNDERSAMPLING** of **MALIGN DATA**, divided into **2 experiments**

# %% [markdown]
# #### EXPERIMENT -I

# %%
display(Image(filename='Resources/Experiment_I.PNG'))

# %% [markdown]
# #### EXPERIMENT -II

# %%
display(Image(filename='Resources/Experiment_II.PNG'))

# %% [markdown]
# ## REFERENCES

# %% [markdown]
# 1. https://towardsdatascience.com/what-to-do-when-your-classification-dataset-is-imbalanced-6af031b12a36

# %% [markdown]
# ---
