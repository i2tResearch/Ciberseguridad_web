# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.feature_selection import SelectKBest, f_classif, mutual_info_regression, chi2, SelectFromModel
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from termcolor import colored

# %% [markdown]
# # ANOVA F-value For Feature Selection Data Pure

# %%
def anovaF(X,y,k=10):
    f_value = SelectKBest(f_classif,k=k)
    X_best = f_value.fit(X,y)
    fig, ax = plt.subplots(figsize = (20,10))
    scores = X_best.scores_
    atrib = X_best.get_support()
    atributos = [data_i.columns[i] for i in list(atrib.nonzero()[0])]
    ax = plt.rcParams["figure.figsize"] = [24,18]
    ax = plt.plot(scores)
    plt.xticks(np.arange(30),np.arange(30), size = 15 )
    plt.yticks(size = 15)
    return atributos, atrib.nonzero()[0]

# %% [markdown]
# # ExtraTreesClassifier Data Pure

# %%
def treesClassifierData(X,y):
    clf = ExtraTreesClassifier(n_estimators = 36)
    clf = clf.fit(X,y)
    model = SelectFromModel(clf, prefit=True)
    best_features_segundo_metodo = X[X.columns[model.get_support(indices = True)]].columns
    return best_features_segundo_metodo

# %% [markdown]
# # LDA Data Pure

# %%
def ldaData(X,y):
    lda = LinearDiscriminantAnalysis(n_components=None)
    X_lda = lda.fit(X, y)
    X_lda
    model = SelectFromModel(X_lda, prefit=True)
    best_features_tercer_metodo = X[X.columns[model.get_support(indices = True)]].columns
    return best_features_tercer_metodo

# %% [markdown]
# # corr_matrix

# %%
def tidy_corr_matrix(corr_mat):

    corr_mat = corr_mat.stack().reset_index()
    corr_mat.columns = ['variable_1','variable_2','r']
    corr_mat = corr_mat.loc[corr_mat['variable_1'] != corr_mat['variable_2'], :]
    corr_mat['abs_r'] = np.abs(corr_mat['r'])
    corr_mat = corr_mat.sort_values('abs_r', ascending=False)
    
    return corr_mat

# %% [markdown]
# # Multicolinialidad

# %%
def VIF(data,best_feature):
    vif_data = pd.DataFrame() 
    vif_data["feature"] = best_feature
    vif_data["VIF"] = [variance_inflation_factor(data[best_feature].values, i) for i in range(len(best_feature))] 
    return vif_data

# %% [markdown]
# # Load Data

# %% [markdown]
# ### Data Pure

# %%
data_i = pd.read_csv('dataA.csv')
data_i.head(1)
# Out:
#    Netflows     p1_d      p2_d      p3_d  duration     max_d     min_d  \
# 0 -0.084787 -0.68541 -0.244709 -0.196223  0.361252 -0.132463 -0.625504
#
#    #packets   Avg_bps   Avg_pps  ...     p2_ip     p3_ip     p1_ib     p2_ib  \
# 0 -0.317443 -0.359303 -0.336093  ... -0.343648 -0.398552 -0.417145 -0.476095
#
#       p3_ib  First_Protocol_ICMP  First_Protocol_ICMP6  First_Protocol_TCP  \
# 0 -0.558694                    0                     0                   1
#
#    First_Protocol_UDP  Type_mine
# 0                   0          0
#
# [1 rows x 31 columns]

# %% [markdown]
# Anova, chi2, forward selection, backward selection, Recursive Feature Elimination, Lasso, Ridge

# %%
y = data_i['Type_mine']
X = data_i.drop(['Type_mine'],axis = 1)

# %%
X.shape
# Out:
# (4733, 30)

# %% [markdown]
# # Select Feature Dataset Pure

# %%
data_i.columns
# Out:
# Index(['Netflows', 'p1_d', 'p2_d', 'p3_d', 'duration', 'max_d', 'min_d',
#        '#packets', 'Avg_bps', 'Avg_pps', 'Avg_bpp', '#Bytes', '#sp', '#dp',
#        'first_sp', 'second_sp', 'third_sp', 'first_dp', 'second_dp',
#        'third_dp', 'p1_ip', 'p2_ip', 'p3_ip', 'p1_ib', 'p2_ib', 'p3_ib',
#        'First_Protocol_ICMP', 'First_Protocol_ICMP6', 'First_Protocol_TCP',
#        'First_Protocol_UDP', 'Type_mine'],
#       dtype='object')

# %%
print(colored(f"Anova", attrs=['bold']))
bestF1Me_p = anovaF(X,y,5)
print(bestF1Me_p)
# Out:
# Anova
# (['p1_d', 'p2_d', 'min_d', 'second_sp', 'second_dp'], array([ 1,  2,  6, 15, 18], dtype=int64))

# %%
print(colored(f"Correlacioón de las mejores caracteristicas del primer metodo", attrs=['bold']))
corr_matrix = X[bestF1Me_p[0]].corr(method='pearson')
tidy_corr_matrix(corr_matrix).head(10)
# Out:
# Correlacioón de las mejores caracteristicas del primer metodo
#    variable_1 variable_2         r     abs_r
# 10      min_d       p1_d  0.987711  0.987711
# 2        p1_d      min_d  0.987711  0.987711
# 1        p1_d       p2_d  0.986604  0.986604
# 5        p2_d       p1_d  0.986604  0.986604
# 7        p2_d      min_d  0.968260  0.968260
# 11      min_d       p2_d  0.968260  0.968260
# 19  second_sp  second_dp  0.903773  0.903773
# 23  second_dp  second_sp  0.903773  0.903773
# 14      min_d  second_dp  0.413384  0.413384
# 22  second_dp      min_d  0.413384  0.413384

# %%
print(colored(f"Multicolinialidad de las mejores caracteristicas del primer metodo", attrs=['bold']))
VIF(data_i,bestF1Me_p[0])
# Out:
# Multicolinialidad de las mejores caracteristicas del primer metodo
#      feature         VIF
# 0       p1_d  102.542838
# 1       p2_d   40.009904
# 2      min_d   45.129893
# 3  second_sp    5.505198
# 4  second_dp    5.545944

# %%
plt.figure(figsize=(5,5))
sns.heatmap(X[bestF1Me_p[0]].corr(), annot=True, cmap="Blues")

# %%
print(colored(f"Segundo metodo", attrs=['bold']))
bestF2Me_p = treesClassifierData(X,y)
bestF2Me_p
# Out:
# Segundo metodo
# Index(['p1_d', 'p2_d', 'p3_d', 'min_d', '#dp', 'first_sp', 'second_sp',
#        'first_dp', 'second_dp'],
#       dtype='object')

# %%
print(colored(f"Correlacioón de las mejores caracteristicas del segundo metodo", attrs=['bold']))
corr_matrix = X[bestF2Me_p].corr(method='pearson')
tidy_corr_matrix(corr_matrix).head(10)
# Out:
# Correlacioón de las mejores caracteristicas del segundo metodo
#    variable_1 variable_2         r     abs_r
# 3        p1_d      min_d  0.987711  0.987711
# 27      min_d       p1_d  0.987711  0.987711
# 1        p1_d       p2_d  0.986604  0.986604
# 9        p2_d       p1_d  0.986604  0.986604
# 11       p2_d       p3_d  0.986034  0.986034
# 19       p3_d       p2_d  0.986034  0.986034
# 12       p2_d      min_d  0.968260  0.968260
# 28      min_d       p2_d  0.968260  0.968260
# 18       p3_d       p1_d  0.964298  0.964298
# 2        p1_d       p3_d  0.964298  0.964298

# %%
print(colored(f"Multicolinialidad de las mejores caracteristicas del segundo metodo", attrs=['bold']))
VIF(data_i,bestF2Me_p)
# Out:
# Multicolinialidad de las mejores caracteristicas del segundo metodo
#      feature         VIF
# 0       p1_d  106.362699
# 1       p2_d  110.315270
# 2       p3_d   41.730145
# 3      min_d   47.991207
# 4        #dp    1.482761
# 5   first_sp    9.504992
# 6  second_sp   15.792557
# 7   first_dp   10.124942
# 8  second_dp   16.106608

# %%
plt.figure(figsize=(5,5))
sns.heatmap(X[bestF2Me_p].corr(), annot=True, cmap="Blues")

# %%
print(colored(f"Criterio experto", attrs=['bold']))
best_feature_expert = ['Avg_bps','Avg_bpp' ,'Avg_pps','p3_ip','p3_ib']
# Out:
# Criterio experto

# %%
print(colored(f"Correlacioón de las mejores caracteristicas del Criterio experto", attrs=['bold']))
corr_matrix = X[best_feature_expert].corr(method='pearson')
tidy_corr_matrix(corr_matrix).head(10)
# Out:
# Correlacioón de las mejores caracteristicas del Criterio experto
#    variable_1 variable_2         r     abs_r
# 23      p3_ib      p3_ip  0.925972  0.925972
# 19      p3_ip      p3_ib  0.925972  0.925972
# 10    Avg_pps    Avg_bps  0.823627  0.823627
# 2     Avg_bps    Avg_pps  0.823627  0.823627
# 1     Avg_bps    Avg_bpp  0.541019  0.541019
# 5     Avg_bpp    Avg_bps  0.541019  0.541019
# 7     Avg_bpp    Avg_pps  0.453374  0.453374
# 11    Avg_pps    Avg_bpp  0.453374  0.453374
# 8     Avg_bpp      p3_ip -0.227160  0.227160
# 16      p3_ip    Avg_bpp -0.227160  0.227160

# %%
print(colored(f"Multicolinialidad de las mejores caracteristicas del segundo metodo", attrs=['bold']))
VIF(data_i,best_feature_expert)
# Out:
# Multicolinialidad de las mejores caracteristicas del segundo metodo
#    feature       VIF
# 0  Avg_bps  3.529267
# 1  Avg_bpp  1.540052
# 2  Avg_pps  3.125442
# 3    p3_ip  7.560062
# 4    p3_ib  7.399004

# %%
plt.figure(figsize=(5,5))
sns.heatmap(X[best_feature_expert].corr(), annot=True, cmap="Blues")

# %%
# best_feature_pure = ['Avg_bps','Avg_bpp' ,'Avg_pps','p3_ip','p3_ib']

# %% [markdown]
# ### Data No Pure

# %%
data_n = pd.read_csv('dataB.csv')
data_n.head(1)
# Out:
#    Netflows      p1_d      p2_d      p3_d  duration     max_d    min_d  \
# 0  4.553656 -0.037927 -0.055406 -0.142137  15.85042 -0.126105 -0.01812
#
#     #packets     Avg_bps    Avg_pps  ...     p2_ip     p3_ip     p1_ib  \
# 0  43.732192  127.789591  32.184816  ...  0.725482  5.594429 -0.046617
#
#       p2_ib     p3_ib  First_Protocol_ICMP  First_Protocol_ICMP6  \
# 0  0.189553  3.916348                    0                     0
#
#    First_Protocol_TCP  First_Protocol_UDP  Type_mine
# 0                   1                   0          1
#
# [1 rows x 31 columns]

# %%
data_n = pd.concat([data_n, data_i[data_i['Type_mine'] == 0]], axis = 0)

# %%
import random
data_n = data_n.reset_index()
indices = list(data_n.index)
random.shuffle(indices)
data_n = data_n.reindex(indices)
data_n.head(1)
# Out:
#        index  Netflows      p1_d      p2_d      p3_d  duration     max_d  \
# 29595  29595  -0.07197 -0.037927 -0.064791 -0.181777 -0.811166 -0.979657
#
#          min_d  #packets   Avg_bps  ...     p2_ip     p3_ip     p1_ib  \
# 29595 -0.01812 -0.096399 -0.035813  ... -0.188257 -0.295768 -0.095017
#
#           p2_ib     p3_ib  First_Protocol_ICMP  First_Protocol_ICMP6  \
# 29595 -0.168736 -0.363409                    0                     1
#
#        First_Protocol_TCP  First_Protocol_UDP  Type_mine
# 29595                   0                   0          1
#
# [1 rows x 32 columns]

# %%
y = data_n['Type_mine']
X = data_n.drop(['Type_mine','index'],axis = 1)

# %% [markdown]
# ### Correlación

# %%
def tidy_corr_matrix(corr_mat):

    corr_mat = corr_mat.stack().reset_index()
    corr_mat.columns = ['variable_1','variable_2','r']
    corr_mat = corr_mat.loc[corr_mat['variable_1'] != corr_mat['variable_2'], :]
    corr_mat['abs_r'] = np.abs(corr_mat['r'])
    corr_mat = corr_mat.sort_values('abs_r', ascending=False)
    
    return(corr_mat)



corr_matrix = X.select_dtypes(include=['float64', 'int']).corr(method='pearson')
tidy_corr_matrix(corr_matrix).head(50)
# Out:
#     variable_1 variable_2         r     abs_r
# 325        #sp        #dp  0.994403  0.994403
# 350        #dp        #sp  0.994403  0.994403
# 191   #packets    Avg_pps  0.935944  0.935944
# 241    Avg_pps   #packets  0.935944  0.935944
# 219    Avg_bps     #Bytes  0.934616  0.934616
# 294     #Bytes    Avg_bps  0.934616  0.934616
# 182   #packets   Netflows  0.909736  0.909736
# 7     Netflows   #packets  0.909736  0.909736
# 12    Netflows        #sp  0.894325  0.894325
# 312        #sp   Netflows  0.894325  0.894325
# 622      p1_ib      p2_ib  0.882671  0.882671
# 647      p2_ib      p1_ib  0.882671  0.882671
# 9     Netflows    Avg_pps  0.880778  0.880778
# 234    Avg_pps   Netflows  0.880778  0.880778
# 246    Avg_pps        #sp  0.877671  0.877671
# 321        #sp    Avg_pps  0.877671  0.877671
# 247    Avg_pps        #dp  0.848970  0.848970
# 347        #dp    Avg_pps  0.848970  0.848970
# 338        #dp   Netflows  0.846807  0.846807
# 13    Netflows        #dp  0.846807  0.846807
# 157      min_d       p1_d  0.843165  0.843165
# 32        p1_d      min_d  0.843165  0.843165
# 644      p2_ib      p1_ip  0.840720  0.840720
# 544      p1_ip      p2_ib  0.840720  0.840720
# 194   #packets        #sp  0.829783  0.829783
# 319        #sp   #packets  0.829783  0.829783
# 345        #dp   #packets  0.784273  0.784273
# 195   #packets        #dp  0.784273  0.784273
# 618      p1_ib      p1_ip  0.784270  0.784270
# 543      p1_ip      p1_ib  0.784270  0.784270
# 566      p2_ip      p1_ip  0.777193  0.777193
# 541      p1_ip      p2_ip  0.777193  0.777193
# 597      p3_ip      p3_ib  0.776751  0.776751
# 672      p3_ib      p3_ip  0.776751  0.776751
# 645      p2_ib      p2_ip  0.762521  0.762521
# 570      p2_ip      p2_ib  0.762521  0.762521
# 649      p2_ib      p3_ib  0.745197  0.745197
# 674      p3_ib      p2_ib  0.745197  0.745197
# 190   #packets    Avg_bps  0.739307  0.739307
# 215    Avg_bps   #packets  0.739307  0.739307
# 134      max_d   duration  0.738696  0.738696
# 109   duration      max_d  0.738696  0.738696
# 293     #Bytes   #packets  0.733066  0.733066
# 193   #packets     #Bytes  0.733066  0.733066
# 242    Avg_pps    Avg_bps  0.699422  0.699422
# 217    Avg_bps    Avg_pps  0.699422  0.699422
# 571      p2_ip      p3_ib  0.686054  0.686054
# 671      p3_ib      p2_ip  0.686054  0.686054
# 568      p2_ip      p3_ip  0.683178  0.683178
# 593      p3_ip      p2_ip  0.683178  0.683178

# %% [markdown]
# ### Multicolinialidad

# %%
vif_data = pd.DataFrame() 
vif_data["feature"] = data_n.columns
vif_data["VIF"] = [variance_inflation_factor(data_n.values, i) for i in range(len(data_n.columns))]

# %%
vif_data[vif_data.VIF>5]
# Out:
#                  feature         VIF
# 1               Netflows   28.658810
# 2                   p1_d    6.092121
# 8               #packets   32.413866
# 9                Avg_bps   16.157129
# 10               Avg_pps   19.270084
# 12                #Bytes   17.956554
# 13                   #sp  803.122094
# 14                   #dp  559.701994
# 21                 p1_ip    6.379052
# 22                 p2_ip    6.113945
# 23                 p3_ip    5.112322
# 24                 p1_ib    7.631880
# 25                 p2_ib   14.692449
# 26                 p3_ib    5.650521
# 28  First_Protocol_ICMP6   91.644342
# 30    First_Protocol_UDP   10.004640
# 31             Type_mine    6.246906

# %%
plt.figure(figsize=(15,15))
sns.heatmap(X.corr(), annot=True, cmap="Reds")

# %% [markdown]
# ### Select Feature

# %%
bestF1Me_n = anovaF(X,y,5)
bestF1Me_n
# Out:
# (['min_d',
#   'second_sp',
#   'second_dp',
#   'First_Protocol_ICMP6',
#   'First_Protocol_TCP'],
#  array([ 6, 15, 18, 27, 28], dtype=int64))

# %%
bestF2Me_n = treesClassifierData(X,y)
bestF2Me_n
# Out:
# Index(['p3_d', 'min_d', 'first_sp', 'third_sp', 'first_dp', 'p1_ip',
#        'First_Protocol_ICMP6', 'First_Protocol_TCP'],
#       dtype='object')

# %%
bestF3Me_n = ldaData(X,y)
bestF3Me_n
# Out:
# Index(['First_Protocol_ICMP6', 'First_Protocol_TCP', 'First_Protocol_UDP'], dtype='object')

# %%
print(colored('Mejores caracteristicas mineria no pura', attrs=['bold']))
best_feature_no_pure = ['min_d', 'second_sp','second_dp','First_Protocol_ICMP6','First_Protocol_TCP']
# Out:
# Mejores caracteristicas mineria no pura

# %%
plt.figure(figsize=(15,15))
sns.heatmap(X[best_feature_no_pure].corr(), annot=True, cmap="Reds")

# %%
a = ['min_d', 'second_sp','second_dp']

# %%
vif_data = pd.DataFrame() 
vif_data["feature"] = a
vif_data["VIF"] = [variance_inflation_factor(X[a].values, i) for i in range(len(X[a].columns))]

# %%
vif_data["VIF"]
# Out:
# 0    1.003112
# 1    1.004316
# 2    1.005084
# Name: VIF, dtype: float64
